# %% [markdown]
# # Midpoint method

# %%
# This is a standard initalisation code - no need to change this
# It loads basic fast array code, plot library and ODE solver
import math
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
# %matplotlib inline
# %config InlineBackend.figure_formats={'retina','png'}

# %%
def f(t, x):
    return x

# %%
## initial time and position
t = 0
x = 1

## step
h = 0.1

## Lists to store the solution, and store thed initial point
ti = [t]
xi = [x]

while t < 1.0:
    f1 = f(t, x)
    x = x+h*f(t+h/2, x+h/2*f1)
    t = t+h
    xi.append(x)
    ti.append(t)

print("ti=", ti)
print("xi=", xi)
# Out:
# ti= [0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999, 1.0999999999999999]
# xi= [1, 1.105, 1.221025, 1.349232625, 1.490902050625, 1.647446765940625, 1.8204286763643904, 2.0115736873826515, 2.22278892455783, 2.456181761636402, 2.714080846608224, 2.9990593355020874]

# %%
fig, ax = plt.subplots(1)

ax.scatter(ti, xi, label="Midpoint")
ax.set_xlabel("$t$")
fig.legend()

# %%
xexact = np.exp(ti)

ax.plot(ti, xexact, label="Exact solution")
fig.legend()
fig
