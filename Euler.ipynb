# %% [markdown]
# # Euler method

# %%
# This is a standard initalisation code - no need to change this
# It loads basic fast array code, plot library and ODE solver
import math
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
# %matplotlib inline
# %config InlineBackend.figure_formats={'retina','png'}

# %%
def f(t, x):
    return x

# %%
## initial time and position
t = 0
tmax = 2
x = 1

## step
h = 0.2

## Lists to store the solution, and store thed initial point
ti = [t]
xi = [x]

while t < tmax:
    x = x+h*f(t, x)
    t = t+h
    xi.append(x)
    ti.append(t)

print("ti=", ti)
print("xi=", xi)
# Out:
# ti= [0, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0, 1.2, 1.4, 1.5999999999999999, 1.7999999999999998, 1.9999999999999998, 2.1999999999999997]
# xi= [1, 1.2, 1.44, 1.728, 2.0736, 2.48832, 2.9859839999999997, 3.5831807999999996, 4.299816959999999, 5.159780351999999, 6.191736422399999, 7.430083706879999]

# %%
fig, ax = plt.subplots(1)

ax.scatter(ti, xi, label="Euler")
ax.set_xlabel("$t$")
fig.legend()

# %%
xexact = np.exp(ti)

ax.plot(ti, xexact, label="Exact solution")
fig.legend()
fig
